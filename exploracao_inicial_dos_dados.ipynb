-- %% [markdown]
-- ###Objetivo: conferir a estrutura das duas tabelas (colunas e tipos), o número de linhas e uma amostra dos registros.

-- %%
%sql
-- Colunas e tipos da tabela de leads (Tabela: olist_marketing_qualified_leads_dataset)
DESCRIBE workspace.portfolio_1_olist.olist_marketing_qualified_leads_dataset;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>mql_id</td><td>string</td><td>null</td></tr><tr><td>first_contact_date</td><td>date</td><td>null</td></tr><tr><td>landing_page_id</td><td>string</td><td>null</td></tr><tr><td>origin</td><td>string</td><td>null</td></tr></tbody></table></div>

-- %%
%sql
-- Colunas e tipos da tabela de negócios fechados (Tabela: olist_closed_deals_dataset)
DESCRIBE portfolio_1_olist.olist_closed_deals_dataset;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
%sql
-- Número de linhas: total de leads (Tabela: olist_marketing_qualified_leads_dataset)
SELECT COUNT(*) AS total_leads
FROM workspace.portfolio_1_olist.olist_marketing_qualified_leads_dataset;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_leads</th></tr></thead><tbody><tr><td>8000</td></tr></tbody></table></div>

-- %%
%sql
-- Número de linhas: total de negócios fechados (Tabela: olist_closed_deals_dataset)
SELECT COUNT(*) AS total_negocios
FROM portfolio_1_olist.olist_closed_deals_dataset;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_negocios</th></tr></thead><tbody><tr><td>842</td></tr></tbody></table></div>

-- %%
%sql
-- Amostra de 10 leads (Tabela: olist_marketing_qualified_leads_dataset)
SELECT * FROM workspace.portfolio_1_olist.olist_marketing_qualified_leads_dataset LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
%sql
-- Amostra de 10 negócios fechados (Tabela: olist_closed_deals_dataset)
SELECT * FROM portfolio_1_olist.olist_closed_deals_dataset LIMIT 10;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- ### Observações
--
-- - A tabela de leads (olist_marketing_qualified_leads_dataset) tem 8000 linhas e 4 colunas, uma linha por lead.
-- - A tabela de negócios fechados (olist_closed_deals_dataset) tem 842 linhas e 14 colunas, uma linha por venda.
-- - A coluna `mql_id` aparece nas duas tabelas e é o que liga cada lead ao negócio que ele gerou.
-- - Os tipos foram reconhecidos corretamente: as datas como `date` e `timestamp`, os campos sim/não como `boolean` e os valores declarados como número. Os cálculos de tempo das próximas perguntas não vão exigir conversão.
-- - Alguns campos da tabela de negócios (`has_company`, `has_gtin`, `average_stock`, `declared_product_catalog_size`) vêm pouco preenchidos, então têm uso limitado nas análises.

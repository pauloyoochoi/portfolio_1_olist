# %% [markdown]
# ##Objetivo: auditar as duas tabelas para garantir que os números não estão distorcidos por duplicatas, registros ausentes ou inconsistências.

# %%
# %sql
-- mql_id duplicados na tabela de leads (Tabela: olist_marketing_qualified_leads_dataset)
SELECT mql_id, COUNT(*) AS qtd
FROM workspace.portfolio_1_olist.olist_marketing_qualified_leads_dataset
GROUP BY mql_id
HAVING COUNT(*) > 1
ORDER BY qtd DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mql_id</th><th>qtd</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- mql_id duplicados na tabela de negocios fechados (Tabela: olist_closed_deals_dataset)
SELECT mql_id, COUNT(*) AS qtd
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
GROUP BY mql_id
HAVING COUNT(*) > 1
ORDER BY qtd DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mql_id</th><th>qtd</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- nulos por coluna na tabela de leads (Tabela: olist_marketing_qualified_leads_dataset)
SELECT
COUNT(*) AS total_linhas,
SUM(CASE WHEN mql_id IS NULL THEN 1 ELSE 0 END) AS mql_id_nulo,
SUM(CASE WHEN first_contact_date IS NULL THEN 1 ELSE 0 END) AS first_contact_date_nulo,
SUM(CASE WHEN landing_page_id IS NULL THEN 1 ELSE 0 END) AS landing_page_id_nulo,
SUM(CASE WHEN origin IS NULL THEN 1 ELSE 0 END) AS origin_nulo
FROM workspace.portfolio_1_olist.olist_marketing_qualified_leads_dataset;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_linhas</th><th>mql_id_nulo</th><th>first_contact_date_nulo</th><th>landing_page_id_nulo</th><th>origin_nulo</th></tr></thead><tbody><tr><td>8000</td><td>0</td><td>0</td><td>0</td><td>60</td></tr></tbody></table></div>

# %%
# %sql
-- nulos por coluna na tabela de negocios fechados (Tabela: olist_closed_deals_dataset)
SELECT 'mql_id' AS coluna,
SUM(CASE WHEN mql_id IS NULL THEN 1 ELSE 0 END) AS nulos,
ROUND(100.0 * SUM(CASE WHEN mql_id IS NULL THEN 1 ELSE 0 END) / COUNT(*), 1) AS pct_nulos
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
UNION ALL
SELECT 'seller_id',
SUM(CASE WHEN seller_id IS NULL THEN 1 ELSE 0 END),
ROUND(100.0 * SUM(CASE WHEN seller_id IS NULL THEN 1 ELSE 0 END) / COUNT(*), 1)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
UNION ALL
SELECT 'sdr_id',
SUM(CASE WHEN sdr_id IS NULL THEN 1 ELSE 0 END),
ROUND(100.0 * SUM(CASE WHEN sdr_id IS NULL THEN 1 ELSE 0 END) / COUNT(*), 1)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
UNION ALL
SELECT 'sr_id',
SUM(CASE WHEN sr_id IS NULL THEN 1 ELSE 0 END),
ROUND(100.0 * SUM(CASE WHEN sr_id IS NULL THEN 1 ELSE 0 END) / COUNT(*), 1)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
UNION ALL
SELECT 'won_date',
SUM(CASE WHEN won_date IS NULL THEN 1 ELSE 0 END),
ROUND(100.0 * SUM(CASE WHEN won_date IS NULL THEN 1 ELSE 0 END) / COUNT(*), 1)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
UNION ALL
SELECT 'business_segment',
SUM(CASE WHEN business_segment IS NULL THEN 1 ELSE 0 END),
ROUND(100.0 * SUM(CASE WHEN business_segment IS NULL THEN 1 ELSE 0 END) / COUNT(*), 1)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
UNION ALL
SELECT 'lead_type',
SUM(CASE WHEN lead_type IS NULL THEN 1 ELSE 0 END),
ROUND(100.0 * SUM(CASE WHEN lead_type IS NULL THEN 1 ELSE 0 END) / COUNT(*), 1)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
UNION ALL
SELECT 'lead_behaviour_profile',
SUM(CASE WHEN lead_behaviour_profile IS NULL THEN 1 ELSE 0 END),
ROUND(100.0 * SUM(CASE WHEN lead_behaviour_profile IS NULL THEN 1 ELSE 0 END) / COUNT(*), 1)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
UNION ALL
SELECT 'has_company',
SUM(CASE WHEN has_company IS NULL THEN 1 ELSE 0 END),
ROUND(100.0 * SUM(CASE WHEN has_company IS NULL THEN 1 ELSE 0 END) / COUNT(*), 1)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
UNION ALL
SELECT 'has_gtin',
SUM(CASE WHEN has_gtin IS NULL THEN 1 ELSE 0 END),
ROUND(100.0 * SUM(CASE WHEN has_gtin IS NULL THEN 1 ELSE 0 END) / COUNT(*), 1)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
UNION ALL
SELECT 'average_stock',
SUM(CASE WHEN average_stock IS NULL THEN 1 ELSE 0 END),
ROUND(100.0 * SUM(CASE WHEN average_stock IS NULL THEN 1 ELSE 0 END) / COUNT(*), 1)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
UNION ALL
SELECT 'business_type',
SUM(CASE WHEN business_type IS NULL THEN 1 ELSE 0 END),
ROUND(100.0 * SUM(CASE WHEN business_type IS NULL THEN 1 ELSE 0 END) / COUNT(*), 1)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
UNION ALL
SELECT 'declared_product_catalog_size',
SUM(CASE WHEN declared_product_catalog_size IS NULL THEN 1 ELSE 0 END),
ROUND(100.0 * SUM(CASE WHEN declared_product_catalog_size IS NULL THEN 1 ELSE 0 END) / COUNT(*), 1)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
UNION ALL
SELECT 'declared_monthly_revenue',
SUM(CASE WHEN declared_monthly_revenue IS NULL THEN 1 ELSE 0 END),
ROUND(100.0 * SUM(CASE WHEN declared_monthly_revenue IS NULL THEN 1 ELSE 0 END) / COUNT(*), 1)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
ORDER BY pct_nulos DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- valores distintos por coluna de texto (string), para achar nulos disfarcados
SELECT 'origin' AS coluna, origin AS valor, COUNT(*) AS qtd
FROM workspace.portfolio_1_olist.olist_marketing_qualified_leads_dataset
GROUP BY origin
UNION ALL
SELECT 'business_segment', business_segment, COUNT(*)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
GROUP BY business_segment
UNION ALL
SELECT 'lead_type', lead_type, COUNT(*)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
GROUP BY lead_type
UNION ALL
SELECT 'lead_behaviour_profile', lead_behaviour_profile, COUNT(*)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
GROUP BY lead_behaviour_profile
UNION ALL
SELECT 'average_stock', average_stock, COUNT(*)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
GROUP BY average_stock
UNION ALL
SELECT 'business_type', business_type, COUNT(*)
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset
GROUP BY business_type
ORDER BY coluna, qtd DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- examinando inconsistências: negocios fechados sem lead de origem
SELECT
COUNT(*) AS fechados_sem_lead
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset AS d
LEFT JOIN workspace.portfolio_1_olist.olist_marketing_qualified_leads_dataset AS l
ON d.mql_id = l.mql_id
WHERE l.mql_id IS NULL;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fechados_sem_lead</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

# %%
# %sql
-- examinando inconsistências: fechamento antes do primeiro contato
SELECT
l.mql_id,
l.first_contact_date,
d.won_date,
DATEDIFF(d.won_date, l.first_contact_date) AS dias_diferenca
FROM workspace.portfolio_1_olist.olist_closed_deals_dataset AS d
JOIN workspace.portfolio_1_olist.olist_marketing_qualified_leads_dataset AS l
ON d.mql_id = l.mql_id
WHERE d.won_date < l.first_contact_date;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mql_id</th><th>first_contact_date</th><th>won_date</th><th>dias_diferenca</th></tr></thead><tbody><tr><td>b91cf8812365f50ff4bda4bcd6206b05</td><td>2018-03-08</td><td>2018-03-06T19:38:55.000Z</td><td>-2</td></tr></tbody></table></div>

# %% [markdown]
# ## Observações
# - Nenhuma das duas tabelas tem `mql_id` duplicado, então a chave que liga lead e negócio é única e a junção entre elas não corre risco de multiplicar linhas.
# - Na tabela de leads (Tabela: olist_marketing_qualified_leads_dataset), a única coluna com campos em branco é `origin`, com 60 nulos em 8000 (menos de 1%). As outras três colunas estão totalmente preenchidas.
# - Na tabela de negócios fechados (Tabela: olist_closed_deals_dataset), quatro colunas estão praticamente vazias: `has_company` (92,5%), `has_gtin` (92,4%), `average_stock` (92,2%) e `declared_product_catalog_size` (91,8%). O `lead_behaviour_profile` tem 21% de nulos, o que exigiria tratamento específico caso venha a ser usado.
# - A coluna `origin` esconde valores que não são canais de verdade: além dos 60 em branco, há 1099 registros como "unknown", 150 como "other" e 65 como "other_publicities". Somados, passam de 17% dos leads e representam origem não identificada.
# - As colunas `business_type` e `lead_type` trazem um valor "other" residual (3 registros cada), que pode ser agrupado com os nulos como "não informado" sem perda relevante.
# - Todo negócio fechado tem um lead de origem correspondente (nenhum registro órfão), o que confirma que a tabela de negócios é um subconjunto da de leads.
# - Foi encontrado um único registro com data de fechamento anterior ao primeiro contato (fechamento dois dias antes do contato), o que é impossível na prática.
